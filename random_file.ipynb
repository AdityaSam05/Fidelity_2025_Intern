# %%
from mysql.connector import connection,connect
import pandas as pd

# %%
con={
    'database':'fil',
    'username':'root',
    'password':'root',
    'host':'localhost',
    'port':3306
}

# %%
try:
    mydb=connection.MySQLConnection(**con)
    print("Connection Ho gya!")
    mydb.cmd_query("SELECT * FROM tips;")
    result=mydb.get_rows()[0]
    for row in result:
        print(row)
except ConnectionError:
    print("Error!!!")
# Out:
# Connection Ho gya!
# (16.99, 1.01, 'Female', 0, 'Sun', 'Dinner', 2, 8.49, 'Christy Cunningham', 3560325168603410, 'Sun2959')
# (10.34, 1.66, 'Male', 0, 'Sun', 'Dinner', 3, 3.45, 'Douglas Tucker', 4478071379779230, 'Sun4608')
# (21.01, 3.5, 'Male', 0, 'Sun', 'Dinner', 3, 7.0, 'Travis Walters', 6011812112971322, 'Sun4458')
# (23.68, 3.31, 'Male', 0, 'Sun', 'Dinner', 2, 11.84, 'Nathaniel Harris', 4676137647685994, 'Sun5260')
# (24.59, 3.61, 'Female', 0, 'Sun', 'Dinner', 4, 6.15, 'Tonya Carter', 4832732618637221, 'Sun2251')
# (25.29, 4.71, 'Male', 0, 'Sun', 'Dinner', 4, 6.32, 'Erik Smith', 213140353657882, 'Sun9679')
# (8.77, 2.0, 'Male', 0, 'Sun', 'Dinner', 2, 4.38, 'Kristopher Johnson', 2223727524230344, 'Sun5985')
# (26.88, 3.12, 'Male', 0, 'Sun', 'Dinner', 4, 6.72, 'Robert Buck', 3514785077705092, 'Sun8157')
# (15.04, 1.96, 'Male', 0, 'Sun', 'Dinner', 2, 7.52, 'Joseph Mcdonald', 3522866365840377, 'Sun6820')
# ...
