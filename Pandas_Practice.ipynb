# %% [markdown]
# Pandas

# %%
# It stores data in the form of series(singular) and dataframes(tabular)
import pandas as pd
import numpy as np

# %%
s=pd.Series([10,2,3,'Data',5.5])
s
# Out:
# 0      10
# 1       2
# 2       3
# 3    Data
# 4     5.5
# dtype: object

# %%
data={
    'name':['Manikaran','Sharma'],
    'score':[100,98]
}
data
# Out:
# {'name': ['Manikaran', 'Sharma'], 'score': [100, 98]}

# %%
df=pd.DataFrame(data)
df
# Out:
#         name  score
# 0  Manikaran    100
# 1     Sharma     98

# %%
dates=pd.date_range('2020-01-05',periods=4,freq='YE')
dates
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31'], dtype='datetime64[ns]', freq='YE-DEC')

# %%
df=pd.DataFrame(np.random.randn(4,4),index=dates,columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2020-12-31 -0.276418  0.735545 -1.997943 -0.878349
# 2021-12-31 -0.455963 -1.006032  0.523373 -0.759644
# 2022-12-31  0.719199  0.028406  0.416666  1.514055
# 2023-12-31 -0.895774  0.215412 -0.934309  0.151465

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
data=pd.read_csv('police.csv')
data.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
data.shape
# Out:
# (91741, 15)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
data['stop_date']=pd.to_datetime(data['stop_date'])

# %%
data.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
data.drop(['county_name',],axis=1,inplace=True)

# %%
data.drop(['search_type'],axis=1,inplace=True)

# %%
data['driver_gender'].fillna(data['driver_gender'].mode()[0],inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13536\3263322256.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['driver_gender'].fillna(data['driver_gender'].mode()[0],inplace=True)

# %%
data['driver_age'].fillna(data['driver_age'].mean(),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13536\389181929.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['driver_age'].fillna(data['driver_age'].mean(),inplace=True)

# %%
data['driver_age_raw'].fillna(data['driver_age_raw'].median(),inplace=True)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13536\1390821914.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['driver_age_raw'].fillna(data['driver_age_raw'].median(),inplace=True)

# %%
data.isna().sum()
# Out:
# stop_date                0
# stop_time                0
# driver_gender            0
# driver_age_raw           0
# driver_age               0
# driver_race           5333
# violation_raw         5333
# violation             5333
# search_conducted         0
# stop_outcome          5333
# is_arrested           5333
# stop_duration         5333
# drugs_related_stop       0
# dtype: int64

# %%
data.groupby('driver_gender').count()
# Out:
#                stop_date  stop_time  driver_age_raw  driver_age  driver_race  \
# driver_gender
# F                  23511      23511           23511       23511        23511
# M                  68230      68230           68230       68230        62897
#
#                violation_raw  violation  search_conducted  stop_outcome  \
# driver_gender
# F                      23511      23511             23511         23511
# M                      62897      62897             68230         62897
#
#                is_arrested  stop_duration  drugs_related_stop
# driver_gender
# F                    23511          23511               23511
# M                    62897          62897               68230

# %%
data.loc[20:30,['driver_gender','stop_outcome','driver_age']]
# Out:
#    driver_gender   stop_outcome  driver_age
# 20             F       Citation   26.000000
# 21             M       Citation   52.000000
# 22             M  Arrest Driver   50.000000
# 23             F       Citation   38.000000
# 24             M  Arrest Driver   26.000000
# 25             M            NaN   34.011333
# 26             M       Citation   41.000000
# 27             F       Citation   28.000000
# 28             M       Citation   21.000000
# 29             M            NaN   34.011333
# 30             M       Citation   46.000000

# %%
data.loc[data['driver_age']>16]
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0     2005-01-02     01:55             M          1985.0        20.0
# 1     2005-01-18     08:15             M          1965.0        40.0
# 2     2005-01-23     23:15             M          1972.0        33.0
# 3     2005-02-20     17:15             M          1986.0        19.0
# 4     2005-03-14     10:00             F          1984.0        21.0
# ...          ...       ...           ...             ...         ...
# 91736 2015-12-31     20:27             M          1986.0        29.0
# 91737 2015-12-31     20:35             F          1982.0        33.0
# 91738 2015-12-31     20:45             M          1992.0        23.0
# 91739 2015-12-31     21:42             M          1993.0        22.0
# 91740 2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# 0           White                        Speeding          Speeding
# ...

# %%
data['driver_gender'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %% [markdown]
# loc:- By label
# iloc: By position

# %%
data.groupby(by=['driver_age']).count()
# Out:
#             stop_date  stop_time  driver_gender  driver_age_raw  driver_race  \
# driver_age
# 15.0                5          5              5               5            5
# 16.0               45         45             45              45           45
# 17.0              585        585            585             585          585
# 18.0             1734       1734           1734            1734         1733
# 19.0             3228       3228           3228            3228         3228
# ...               ...        ...            ...             ...          ...
# 88.0                2          2              2               2            2
# 89.0                1          1              1               1            1
# 90.0                1          1              1               1            1
# 94.0                1          1              1               1            1
# 99.0                1          1              1               1            1
#
# ...

# %%
data.query('driver_age>50').head()
# Out:
#     stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 21 2005-08-07     16:50             M          1953.0        52.0       White
# 33 2005-09-28     07:45             M          1953.0        52.0       White
# 34 2005-09-29     23:45             M          1947.0        58.0       White
# 51 2005-10-01     12:50             M          1950.0        55.0       White
# 54 2005-10-01     16:45             M          1954.0        51.0       White
#
#               violation_raw         violation  search_conducted stop_outcome  \
# 21  Other Traffic Violation  Moving violation             False     Citation
# 33  Other Traffic Violation  Moving violation             False     Citation
# 34                 Speeding          Speeding             False     Citation
# 51                 Speeding          Speeding             False     Citation
# 54                 Speeding          Speeding             False     Citation
#
# ...

# %%
data.query('driver_age < 18 and driver_gender=="F"').head()
# Out:
#      stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 276 2005-10-10     09:10             F          1988.0        17.0
# 597 2005-10-23     16:03             F          1988.0        17.0
# 642 2005-10-24     19:53             F          1988.0        17.0
# 898 2005-11-01     23:40             F          1988.0        17.0
# 950 2005-11-04     01:50             F          1988.0        17.0
#
#     driver_race            violation_raw         violation  search_conducted  \
# 276       White  Other Traffic Violation  Moving violation             False
# 597       White                 Speeding          Speeding             False
# 642       White                 Speeding          Speeding             False
# 898       White                 Speeding          Speeding             False
# 950       White  Other Traffic Violation  Moving violation             False
#
#     stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
data.duplicated().sum()
# Out:
# 480

# %%
# Write a function in which you provide the year. it calculates the age
from datetime import datetime
def get_age(dob):
    current_year=datetime.now().year
    age=current_year-dob
    return age

# %%
# data['driver_age'] = data['driver_age'].apply(lambda x: datetime.now().year-x)

# %%
data.head()
# Out:
#    stop_date stop_time driver_gender  driver_age_raw  driver_age driver_race  \
# 0 2005-01-02     01:55             M          1985.0        20.0       White
# 1 2005-01-18     08:15             M          1965.0        40.0       White
# 2 2005-01-23     23:15             M          1972.0        33.0       White
# 3 2005-02-20     17:15             M          1986.0        19.0       White
# 4 2005-03-14     10:00             F          1984.0        21.0       White
#
#       violation_raw violation  search_conducted   stop_outcome is_arrested  \
# 0          Speeding  Speeding             False       Citation       False
# 1          Speeding  Speeding             False       Citation       False
# 2          Speeding  Speeding             False       Citation       False
# 3  Call for Service     Other             False  Arrest Driver        True
# 4          Speeding  Speeding             False       Citation       False
#
#   stop_duration  drugs_related_stop
# ...

# %%
data['driver_age_bins']=pd.qcut(data['driver_age'],q=5)

# %%
data['driver_age_bins']
# Out:
# 0        (14.999, 23.0]
# 1        (34.011, 45.0]
# 2        (28.0, 34.011]
# 3        (14.999, 23.0]
# 4        (14.999, 23.0]
#               ...
# 91736    (28.0, 34.011]
# 91737    (28.0, 34.011]
# 91738    (14.999, 23.0]
# 91739    (14.999, 23.0]
# 91740      (45.0, 99.0]
# Name: driver_age_bins, Length: 91741, dtype: category
# Categories (5, interval[float64, right]): [(14.999, 23.0] < (23.0, 28.0] < (28.0, 34.011] < (34.011, 45.0] < (45.0, 99.0]]

# %%
data['driver_gender'].value_counts()
# Out:
# driver_gender
# M    68230
# F    23511
# Name: count, dtype: int64

# %%
pd.crosstab(data['is_arrested'],data['driver_gender'],normalize='columns')
# Out:
# driver_gender        F         M
# is_arrested
# False          0.97465  0.962908
# True           0.02535  0.037092

# %% [markdown]
# Working on the Tips Dataset

# %%
data1=pd.read_csv('tips.csv')

# %%
data1.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
data1.shape
# Out:
# (244, 11)

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
avg=data1.groupby('smoker')['tip'].count()

# %%
avg
# Out:
# smoker
# No     151
# Yes     93
# Name: tip, dtype: int64

# %%
depends=data1.groupby('size')['tip'].mean()
depends
# Out:
# size
# 1    1.437500
# 2    2.582308
# 3    3.393158
# 4    4.135405
# 5    4.028000
# 6    5.225000
# Name: tip, dtype: float64

# %%
mat=data1[['size','tip']].corr
mat
# Out:
# <bound method DataFrame.corr of      size   tip
# 0       2  1.01
# 1       3  1.66
# 2       3  3.50
# 3       2  3.31
# 4       4  3.61
# ..    ...   ...
# 239     3  5.92
# 240     2  2.00
# 241     2  2.00
# 242     2  1.75
# 243     2  3.00
#
# [244 rows x 2 columns]>

# %%
import seaborn as sns

# %%
data1['smoker']=data1['smoker'].apply(lambda x: 1 if x=='Yes' else 0)

# %%
username='root'
password='root'
host='localhost'
database='fil'
port=3306

# %%
from sqlalchemy import create_engine
engine=create_engine("mysql+pymysql://{0}:{1}@{2}/{3}".format(username,password,host,database))

# %%
data1.to_sql('tips',engine,index=False) # writes data from dataframe to sql table names
# Out:
# 244

# %%
# Adding a new row with null values
new=pd.DataFrame([[None]*len(data1.columns)],columns=data1.columns)
data1=pd.concat([data1,new],ignore_index=False)
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_13536\184915473.py:2: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   data1=pd.concat([data1,new],ignore_index=False)

# %%
data1.to_sql('tips1',engine,index=False) # writes data from dataframe to sql table names
# Out:
# 247
